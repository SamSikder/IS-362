# %% [markdown]
# # Assignment 7 – Web APIs
#
# Name: Sam Sikder
# Course: IS 362
# Date: April 18, 2026
#
# For this assignment, I selected a New York Times API and used Python to retrieve JSON data and convert it into a pandas DataFrame.

# %% [markdown]
# ## Importing Libraries
#
# The requests library was used to connect to the API, and pandas was used to organize the JSON data into a DataFrame.

# %%
import requests
import pandas as pd

# %%
api_key = "zDwPms51NwgCbrPsIIIoBzdGmn7N8Bajhe0zoor9X6b7i7K8"

# %%
url = f"https://api.nytimes.com/svc/mostpopular/v2/viewed/7.json?api-key={api_key}"

response = requests.get(url)

response.status_code
# Out:
# 200

# %%
data = response.json()

articles = data["results"]

df = pd.DataFrame(articles)

df.head()
# Out:
#                                                  uri  \
# 0  nyt://article/db1a6ed9-380c-5e9a-8d3c-914bde4d...
# 1  nyt://article/c6262605-4132-560e-a13d-328918cb...
# 2  nyt://article/52e70095-83cd-51ce-ae58-74124639...
# 3  nyt://article/082d1996-e31b-5e44-bb95-5340bb34...
# 4  nyt://article/a1aaf500-1e41-5e31-91da-64d16a75...
#
#                                                  url               id  \
# 0  https://www.nytimes.com/2026/04/14/us/florida-...  100000010840508
# 1  https://www.nytimes.com/2026/04/14/us/politics...  100000010841613
# 2  https://www.nytimes.com/2026/04/15/us/yale-rep...  100000010840797
# 3  https://www.nytimes.com/2026/04/18/us/politics...  100000010774581
# 4  https://www.nytimes.com/2026/04/17/opinion/laf...  100000010844525
#
#           asset_id          source published_date              updated  \
# 0  100000010840508  New York Times     2026-04-14  2026-04-16 20:40:02
# 1  100000010841613  New York Times     2026-04-14  2026-04-15 13:19:41
# ...

# %%
df = df[[
    "title",
    "abstract",
    "byline",
    "published_date",
    "section",
    "source",
    "url"
]]

df.head()
# Out:
#                                                title  \
# 0  Surgeon Who Removed Wrong Organ From Patient I...
# 1  Vance Says the Pope Should Be More Careful Whe...
# 2  Yale Report Finds Colleges Deserve Blame for H...
# 3  The Inside Story of Five Days That Remade the ...
# 4  A Stunning New Verdict Rewrites the Rules of C...
#
#                                             abstract  \
# 0  Dr. Thomas Shaknovsky tried to persuade his co...
# 1  The vice president, who is Catholic, took issu...
# 2  A 10-member committee offered a brutal assessm...
# 3  Secret memos obtained by The New York Times il...
# 4  The profit motive was on trial. The verdict wa...
#
#                            byline published_date  section          source  \
# 0                   By Vjosa Isai     2026-04-14     U.S.  New York Times
# 1            By Anton Troianovski     2026-04-14     U.S.  New York Times
# 2                 By Alan Blinder     2026-04-15     U.S.  New York Times
# ...

# %% [markdown]
# ## Summary
#
# In this assignment, I used the New York Times Most Popular API to retrieve article data in JSON format. Using Python and the requests library, I accessed the API and converted the JSON response into a pandas DataFrame. The DataFrame organizes article information such as title, author, publication date, section, and URL.
